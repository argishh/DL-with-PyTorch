# %% [markdown]
# #### **Using bounding boxes for object recognition**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### To use images in pytorch, we must convert pixels to tensors.
#
# There are two methods to transform pixels to tensors :-
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### **Drawing bounding boxes on images**
#
# We can do this using `draw_bounding_boxes()` method from `torchvision.utils`
#
# ![image.png](attachment:image.png)

# %%
import torch
from torchvision.utils import draw_bounding_boxes
import matplotlib.pyplot as plt

bbox = torch.tensor([x_min, y_min, x_max, y_max])
bbox = bbox.unsqueeze(0)
bbox_image = draw_bounding_boxes(image_tensor, bbox, widith=3, colors='red')

transform = transforms.compose([transform.ToPILImage()])
pil_image = transform(bbox_image)

plt.imshow(pil_image)
