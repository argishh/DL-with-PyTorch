# %% [markdown]
# #### **Evaluating Object Recognition Models**
#
# requirements -
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Widely used metric to evaluate model prediction bounding boxes -
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import torch
from torchvision.ops import box_iou

        # x_min, y_min, x_max, y_max
bbox1 = [50, 50, 150, 150]
bbox2 = [100, 100, 200, 200]

bbox1 = torch.tensor(bbox1).unsqueeze(0)
bbox2 = torch.tensor(bbox2).unsqueeze(0)

iou = box_iou(bbox1, bbox2)
print(iou)
# Out:
# tensor([[0.1429]])

# %% [markdown]
# #### **Predicting bounding boxes**

# %%
# Example

model.eval()

with torch.no_grad():
    output = model(input_image)
    
print(output)

# %%
boxes = output[0]['boxes']
scores = output[0]['scores']

# %% [markdown]
# #### **Dealing with multiple bounding boxes**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Example
from torchvision.ops import nms

box_indices = nms(
    boxes = boxes,
    scores = scores,
    iou_threshold=0.5,
)

print(box_indices)

# %% [markdown]
# Where,
#
# ![image.png](attachment:image.png)

# %%
# Filtered boxes will be -

filtered_boxes = boxes[box_indices]
